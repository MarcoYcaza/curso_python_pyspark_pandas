# %%
# ciclo for
# while
# input
# métodos de strings

  # Ejercicio para crear funciones de contatenación de nombre y apellido
  # Ejercicio para generar resultado de dadoos


# Compresión de listas
# Operador ternario
# Función lambda

# %%
for i in [1,3,4,5,8,7]:
  print(i*2)
# Out:
# 2
# 6
# 8
# 10
# 16
# 14

# %%
for _ in range(2):
  print("Hola")
# Out:
# Hola
# Hola

# %%
resultado = input("Escribir algun dato: ")
# Out:
# Escribir algun dato: Marco

# %%
resultado
# Out:
# 'Marco'

# %%
flag = True

while(flag):
  
  resultado = input("Escribir algun dato: ")

  if resultado == "yes":
    #break
    flag = False
# Out:
# Escribir algun dato: asasd
# Escribir algun dato: adsagag
# Escribir algun dato: adasdasd
# Escribir algun dato: asdasdasd
# Escribir algun dato: yes

# %% [markdown]
# # Cadenas de texto

# %%
cadena = "hola mundo"

# %%
# for caracter in cadena:
#   print(type(caracter))

# %%
#dir(str)

# %%
cadena = " Hola mundo "

# %%
cadena.strip()
# Out:
# 'Hola mundo'

# %%
cadena.lstrip()
# Out:
# 'Hola mundo '

# %%
cadena.rstrip()
# Out:
# ' Hola mundo'

# %%
help(cadena.ljust)
# Out:
# Help on built-in function ljust:
#
# ljust(width, fillchar=' ', /) method of builtins.str instance
#     Return a left-justified string of length width.
#
#     Padding is done using the specified fill character (default is a space).

# %%
len(cadena)
# Out:
# 12

# %%
len(cadena.ljust(15))
# Out:
# 15

# %%
cadena.ljust(15)
# Out:
# ' Hola mundo    '

# %%
cadena.rjust(15)
# Out:
# '    Hola mundo '

# %%
"Hola Mundo".upper()
# Out:
# 'HOLA MUNDO'

# %%
"Hola-Mundo".split("-")
# Out:
# ['Hola', 'Mundo']

# %%
"Hola-Mundo".replace("-"," ")
# Out:
# 'Hola Mundo'

# %%
"Hola" + "Mundo"
# Out:
# 'HolaMundo'

# %%
# variable = ["Lunes" , "Martes" , "Miercoles"]

variable = "ABCDEFG"

"-".join(variable)
# Out:
# 'A-B-C-D-E-F-G'

# %%
"_".join("Marco Ycaza".split())
# Out:
# 'Marco_Ycaza'

# %% [markdown]
# # modulo string

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
string.ascii_letters+"ñ"
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZñ'

# %%
#dir(string)

# %%
cadena_nueva = ""

for caracter in "#$%&\'00111565478942119687":

  if caracter not in string.punctuation:

    #cadena_nueva = cadena_nueva+caracter
    cadena_nueva += caracter


print(cadena_nueva)
# Out:
# 00111565478942119687
