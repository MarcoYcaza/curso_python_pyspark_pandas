# %% [markdown]
# Primera clase de python

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Tipos de datos

# %%
# enteros      - int
print(1 + 2)
# decimales      - float
print(25.4 + 78.6 )   
# suma de enteros y decimales  - float
print(45 + 75.6)
# Out:
# 3
# 104.0
# 120.6

# %%
import math

7**3  # Elevar a una potencia

math.floor(74.3)  # Sacar el minimo entero
# Out:
# 74

# %%
78//5  # cociente
# Out:
# 15

# %%
78 % 5 # resto
# Out:
# 3

# %%
((78+59) // 8 )**3
# Out:
# 4913

# %%
# Cadenas de texto

variable1 = "Hola Mundo"
variable2 = 'Hola Mundo'

# %%
type(variable1)
# Out:
# str

# %%
# Booleanos
True

False
# Out:
# False

# %%
# Iterables

lista = [1,2,3,4,5,6]

# %% [markdown]
# Conversiones Basicas

# %%
str(250)
# Out:
# '250'

# %%
int("2564")
# Out:
# 2564

# %% [markdown]
# Clausulas de condicion

# %%
input("Escriba un numero: ")
# Out:
# Escriba un numero: 25
# '25'

# %%
numero = int(input("Escriba un numero: "))

#  >
#  <
# ==
# >=
# <=

# or 
# and

if ( numero > 0) and (numero <100): 
  print("El numero es mayor a 100")
else:
  print("El numero es menor a 100")
# Out:
# Escriba un numero: -1
# El numero es menor a 100

# %% [markdown]
# Ciclos de recorrido

# %%
lista = [1,2,3]

# %%
#FOR

# %%
for i in lista:
  print(i*2)
# Out:
# 2
# 4
# 6

# %%
#WHILE

# %%
numero = 20

while(True):

  if numero <= 10:
    break

  #print(numero)
  numero = numero -1

# %%
not False
# Out:
# True

# %%
numero = 20

condicion_de_parada =  False

while(not condicion_de_parada):

  if numero <= 10:
    condicion_de_parada = True

  #print(numero)
  numero = numero -1
