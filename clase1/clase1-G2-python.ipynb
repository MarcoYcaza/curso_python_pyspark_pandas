# %% [markdown]
#  Haciendo un Simil de la diferencia entre un método en Java y Python
#
#
# ```
#  boolean InOrder(int x, int y, int z)
#   {
#      if (x <= y && y <= z)
# 	      return true;
#      else
# 	      return false;
#   }
# ```
# Puede ser colapsado a:
#
# ```
# public boolean InOrder(int x, int y, int z){if (x <= y && y <= z) return true; else return false;}
# ```
#
# Pero en Python la sintaxis obliga a usar la correcta identación dado que no existe las aperturas con llaves o fin de línea de código con ";"
#
# Por ejemplo , esta identación es correcta
#
# ```
# def InOrder(x,y,z):
#         if (x<=y and y<=z):
#             return True
#         else:
#             return False
# ```
# y esta no:
#
# ```
# def InOrder(x,y,z): if (x<=y and y<=z): return True else: return False
# ```

# %% [markdown]
# ## Operadores matemáticos

# %%
# multiplicación
#2*3

# potencia
#2**3

# modulo (devuelve el resto)
#22%8

# division 
#22/8

# division entera
#22//8

#Todo lo anterior
#(9 - 5)*((7//4) / (3-1)) **2

# %% [markdown]
# # Tipos  de datos

# %%
###  Los más comunes:

# Enteros
variable  = 2022

# Flotantes
variable  = 89.5

# Strings
variable  = "Hola Mundo"

# Booleans
variable  = True or False

# listas
variable = [1,2,3,4,5]

# tuplas
variable = (1,2,3)

# diccionarios
variable = {
    "key1" : 1 ,
    "key2" : 2
}

### Los menos comunes:
# set
# frozen-set

# %%
import random


def devolver_resultado_dados():
  return (random.randint(1,6), random.randint(1,6))


dado1 , dado2 = devolver_resultado_dados()

# %%
a = 1
b = 4

# %%
#temp = a
#a = b
#b = temp

# %%
(a,b) = (b,a)

# %%
#help()

# %%
import random

# %%
x = random.random()        #  [0,1)
y = random.randint(1,6)    #  [a,b]
z = random.randrange(1,7)  #  [a,b)

# %%
#help(random.randrange)

# %% [markdown]
# # Funciones

# %%
def saludarIntegrantes():
  """
  Esta funcion tiene la tarea de saludar
  """
  print("Hola a todos !!")

# %%
saludarIntegrantes()
# Out:
# Hola a todos !!

# %%
help(saludarIntegrantes)
# Out:
# Help on function saludarIntegrantes in module __main__:
#
# saludarIntegrantes()
#     Esta funcion tiene la tarea de saludar

# %%
#help(str)

# %%
def sumarLosArgumentos(a,b):

  return a + b

# %%
sumarLosArgumentos(34,56)
# Out:
# 90

# %%
str(2022)
# Out:
# '2022'

# %%
int("45")
# Out:
# 45

# %%
float("-25.89")
# Out:
# -25.89

# %%
import math

math.pi
#math.e
# Out:
# 3.141592653589793

# %%
#import decimal
#help(decimal)

# %%
#random.uniform(-1,1)

# %%
from random import random as rnd

N = 10000000

contador_circulo = 0

for i in range(N):

  x , y = (rnd() , rnd())

  if (x-0.5)**2 + (y-0.5)**2 <= (0.5**2) :

    contador_circulo = contador_circulo+1

razon = contador_circulo*4/N

print(razon)
# Out:
# 3.1406756
