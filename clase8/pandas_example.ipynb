# %%
import pandas as pd

# %%
#!pip3.8 install matplotlib

# %%
df = pd.read_csv(r"C:\Users\marco\OneDrive\proyectos\Capacitaciones\curso_python_pyspark_pandas\clase4\inversiones.csv")

# %%
df.dtypes
# Out:
# user_name     object
# amount       float64
# id             int64
# date          object
# dtype: object

# %%
df.amount.plot()
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#              amount            id
# count     99.000000  9.900000e+01
# mean   42237.710303  2.280815e+09
# std    34381.899535  2.709798e+09
# min     6099.000000  1.000006e+09
# 25%     9140.560000  1.007488e+09
# 50%    25641.750000  1.009014e+09
# 75%    76851.695000  1.021534e+09
# max    98432.190000  8.000070e+09
