# %%
import pandas as pd 

df_public =  pd.read_csv("./data/survey_results_public.csv" , index_col = 'Respondent')
df_schema =  pd.read_csv("./data/survey_results_schema.csv", index_col = 'Column')

# %%
#df_public.dtypesOpSys
#df_public

# %%
#df_public

# %%
pd.set_option('display.max_columns', 60)

# %%
df_public['ConvertedComp'].count()
# Out:
# 34756

# %%
len(df_public['ConvertedComp'])
# Out:
# 64461

# %%
df_public['ConvertedComp'].mean()
df_public['ConvertedComp'].median()
# Out:
# 54049.0

# %%
df_public.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df_public['OpSys'].value_counts(normalize=True)
# Out:
# Windows        0.483211
# Linux-based    0.265562
# MacOS          0.250320
# BSD            0.000907
# Name: OpSys, dtype: float64

# %% [markdown]
# Group By

# %%
#df_public.loc[ df_public.Country == '"Peru"]

grouped_object = df_public.groupby(['Country'])

grouped_object.get_group('Peru')
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 413         I am a developer by profession      Yes  38.0         16  Monthly
# 738         I am a developer by profession      Yes  22.0         18  Monthly
# 921         I am a developer by profession      Yes  21.0         16  Monthly
# 2741        I am a developer by profession      Yes  25.0         14  Monthly
# 3058        I am a developer by profession       No  19.0         15  Monthly
# ...                                    ...      ...   ...        ...      ...
# 62678       I am a developer by profession      Yes   NaN        NaN      NaN
# 63034       I am a developer by profession      Yes   NaN        NaN      NaN
# 64682       I am a developer by profession      Yes   NaN        NaN      NaN
# 64703          I code primarily as a hobby      Yes   NaN        NaN      NaN
# 18803                                  NaN      Yes  45.0         18      NaN
#
# ...

# %%
#grouped_object.count()

# %%
grouped_object = df_public.groupby(['Country'])

grouped_object['ConvertedComp'].mean()
# Out:
# Country
# Afghanistan                             148290.125000
# Albania                                  25611.000000
# Algeria                                  10362.812500
# Andorra                                  88640.000000
# Angola                                    5292.000000
#                                             ...
# Venezuela, Bolivarian Republic of...      6280.611111
# Viet Nam                                 28342.605769
# Yemen                                    36000.000000
# Zambia                                   17506.400000
# Zimbabwe                                 26338.181818
# Name: ConvertedComp, Length: 183, dtype: float64

# %%
#grouped_object.mean()

# %%
grouped_object = df_public.groupby(['Country'])

grouped_object['ConvertedComp'].agg(['median', 'mean' , 'std' ]).loc['Peru']
# Out:
# median    13068.500000
# mean      23254.884615
# std       49079.206820
# Name: Peru, dtype: float64

# %%
df_public["LanguageWorkedWith"].str.contains('Python').value_counts()
# Out:
# False    32091
# True     25287
# Name: LanguageWorkedWith, dtype: int64

# %%
country_filter = df_public["Country"] == "Spain"

df_public.loc[country_filter]["LanguageWorkedWith"].str.contains('Python').value_counts()
# Out:
# False    608
# True     448
# Name: LanguageWorkedWith, dtype: int64

# %% [markdown]
# Grouping Approach

# %%
grouped_object = df_public.groupby(['Country'])

redux_function = lambda x : x.str.contains("Python").sum()

grouped_object["LanguageWorkedWith"].apply(redux_function)
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64
