# %% [markdown]
# Decimales de alta precisión

# %%
from decimal import *
getcontext().prec = 5

# %%
0.1 +0.2
# Out:
# 0.30000000000000004

# %%
float(Decimal(0.1) + Decimal(0.2)) == 0.3    # Sale True
0.1+0.2 == 0.3                               # sale False

# %%
# if else
# ciclo for
# métodos de strings

# while
# input
  # Ejercicio para crear funciones de contatenación de nombre y apellido
  # Ejercicio para generar resultado de dadoos


# Compresión de listas
# Operador ternario
# Función lambda

# %%
# == , > ,< , >= ,<= !=

# and or - in

# and : salida inminente 
# or  : salida inminente
#           vs
# &  :  evaluación completa
# |  :  evaluación completa 


a = "hola"
b = "Hola"

#En java
#   a.equals(b)

m = 100
n = 23

if (m > n) or (1/0) :
  print(True)
else:
  print(False)

#--------------------- 

m = 1
n = 23

#if (m > n) or (1/0) :
#  print(True)
#else:
#  print(False)
# Out:
# True

# %%
m = 100
n = 23

#if (m > n) | (1/0) :
#  print(True)
#else:
#  print(False)

# %%
a , b = 5 ,5

if (a > b):
  print("es mayor")
elif(b < a):
  print("es menor")
else:
  print("son iguales")
# Out:
# son iguales

# %%
a =  5, 5
type(a)

a = (4,)
type(a)
# Out:
# tuple

# %%
#",".join(dir(a))

# %%
#",".join(dir([1,2,3,4]))

# %%
import sys

t1 = [1,2,3,4,4,5] 

t2 = (1,2,3,4,4,5)

print(sys.getsizeof(t1))
print(sys.getsizeof(t2))
# Out:
# 120
# 104

# %%
#list(range(0,10,))

# %%
lista = []

for i in range(5):
  lista.append(i)
